# %%
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

data = load_iris()
X = data.data

kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)

plt.figure(figsize=(10, 6))
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y_kmeans, palette='viridis', s=100)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', label='Центры кластеров', marker='X')
plt.xlabel(data.feature_names[0])
plt.ylabel(data.feature_names[1])
plt.title("Кластеры, выделенные K-Means на наборе данных Iris")
plt.legend()
plt.show()
